# %%
import polars as pl

# %%
data = pl.read_csv("data/websites.csv")

# %%
data
# Out:
# shape: (1_937, 5)
# ┌────────┬───────────────────────────┬──────┬───────────────────────────┬──────────────────────────┐
# │ web_id ┆ url                       ┆ kind ┆ title                     ┆ text                     │
# │ ---    ┆ ---                       ┆ ---  ┆ ---                       ┆ ---                      │
# │ i64    ┆ str                       ┆ str  ┆ str                       ┆ str                      │
# ╞════════╪═══════════════════════════╪══════╪═══════════════════════════╪══════════════════════════╡
# │ 1      ┆ https://alfabank.ru/      ┆ html ┆ Альфа-Банк - кредитные и  ┆ Рассчитайте выгоду       │
# │        ┆                           ┆      ┆ дебет…                    ┆ Расчёт каль…             │
# │ 2      ┆ https://alfabank.ru/a-clu ┆ html ┆ А-Клуб. Деньги имеют      ┆ Брокерские услуги        │
# │        ┆ b/                        ┆      ┆ значение                  ┆ Открытие бро…            │
# ...
